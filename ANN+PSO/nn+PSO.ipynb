# %%
# Import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


# Import PySwarms
import pyswarms as ps

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
    df = pd.read_csv("Leeds02.csv")
    X = df.iloc[:, :-1].values
    y = df.iloc[:, -1].values

# %%
def forward_prop(params):
    """Forward propagation as objective function

    This computes for the forward propagation of the neural network, as
    well as the loss. It receives a set of parameters that must be
    rolled-back into the corresponding weights and biases.

    Inputs
    ------
    params: np.ndarray
        The dimensions should include an unrolled version of the
        weights and biases.

    Returns
    -------
    float
        The computed negative log-likelihood loss given the parameters
    """
    # Neural network architecture
    n_inputs = 12
    n_hidden = 5
    n_classes = 3

    # Roll-back the weights and biases
    W1 = params[0:60].reshape((n_inputs,n_hidden))
    b1 = params[60:65].reshape((n_hidden,))
    W2 = params[65:80].reshape((n_hidden,n_classes))
    b2 = params[80:83].reshape((n_classes,))

    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2

    # Compute for the softmax of the logits
    exp_scores = np.exp(logits)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

    # Compute for the negative log likelihood
    N = 2203 # Number of samples
    corect_logprobs = -np.log(probs[range(N), y])
    loss = np.sum(corect_logprobs) / N

    return loss

# %%
def f(x):
    """Higher-level method to do forward_prop in the
    whole swarm.

    Inputs
    ------
    x: numpy.ndarray of shape (n_particles, dimensions)
        The swarm that will perform the search

    Returns
    -------
    numpy.ndarray of shape (n_particles, )
        The computed loss for each particle
    """
    n_particles = x.shape[0]
    j = [forward_prop(x[i]) for i in range(n_particles)]
    return np.array(j)

# %%
# %%time
# Initialize swarm
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

# Call instance of PSO
dimensions = (4 * 20) + (20 * 3) + 20 + 3
optimizer = ps.single.GlobalBestPSO(n_particles=100, dimensions=dimensions, options=options)

# Perform optimization
cost, pos = optimizer.optimize(f, iters=1000)
# Out:
# 2019-11-23 01:12:37,211 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                              |0/1000
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                             |0/1000, best_cost=0.523
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                             |0/1000, best_cost=0.496
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                             |2/1000, best_cost=0.496
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                             |2/1000, best_cost=0.473
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                             |2/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|▏                                                            |4/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|▏                                                            |4/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|▏                                                            |4/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▎                                                            |6/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▎                                                            |6/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▍                                                            |7/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▍                                                            |7/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▍                                                            |7/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▌                                                            |9/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▌                                                            |9/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▌                                                            |9/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▋                                                           |11/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▋                                                           |11/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▋                                                           |11/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▊                                                           |13/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▊                                                           |13/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   1%|▊                                                           |13/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|▉                                                           |15/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|▉                                                           |15/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|▉                                                           |15/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█                                                           |17/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█                                                           |17/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█                                                           |17/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▏                                                          |19/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▏                                                          |19/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▏                                                          |19/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▎                                                          |21/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▎                                                          |21/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▎                                                          |21/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▍                                                          |23/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▍                                                          |23/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▍                                                          |23/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▌                                                          |25/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▌                                                          |25/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   2%|█▌                                                          |25/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▌                                                          |27/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▌                                                          |27/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▌                                                          |27/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▋                                                          |29/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▋                                                          |29/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▋                                                          |29/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▊                                                          |31/1000, best_cost=0.445
# pyswarms.single.global_best:   3%|█▊                                                          |31/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▊                                                          |31/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▉                                                          |33/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▉                                                          |33/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   3%|█▉                                                          |33/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██                                                          |35/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██                                                          |35/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██                                                          |35/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▏                                                         |37/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▏                                                         |37/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▏                                                         |37/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▎                                                         |39/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▎                                                         |39/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▎                                                         |39/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▍                                                         |41/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▍                                                         |41/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▍                                                         |41/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▌                                                         |43/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▌                                                         |43/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▌                                                         |43/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▋                                                         |45/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▋                                                         |45/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   4%|██▋                                                         |45/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▊                                                         |47/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▊                                                         |47/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▊                                                         |47/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▉                                                         |49/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▉                                                         |49/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|██▉                                                         |49/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███                                                         |51/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███                                                         |51/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███                                                         |51/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                        |53/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                        |53/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                        |53/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▎                                                        |55/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▎                                                        |55/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▎                                                        |55/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▍                                                        |57/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▍                                                        |57/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▍                                                        |57/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▌                                                        |59/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▌                                                        |59/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▌                                                        |59/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▋                                                        |61/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▋                                                        |61/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▋                                                        |61/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▊                                                        |63/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▊                                                        |63/1000, best_cost=0.445
# pyswarms.single.global_best:   6%|███▊                                                        |63/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▉                                                        |65/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▉                                                        |65/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   6%|███▉                                                        |65/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████                                                        |67/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████                                                        |67/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████                                                        |67/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▏                                                       |69/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▏                                                       |69/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▏                                                       |69/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▎                                                       |71/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▎                                                       |71/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▎                                                       |71/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▍                                                       |73/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▍                                                       |73/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   7%|████▍                                                       |73/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |75/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |75/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |75/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |77/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |77/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▌                                                       |77/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▋                                                       |79/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▋                                                       |79/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▋                                                       |79/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▊                                                       |81/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▊                                                       |81/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▊                                                       |81/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▉                                                       |83/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▉                                                       |83/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|████▉                                                       |83/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|█████                                                       |85/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|█████                                                       |85/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   8%|█████                                                       |85/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▏                                                      |87/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▏                                                      |87/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▏                                                      |87/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▎                                                      |89/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▎                                                      |89/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▎                                                      |89/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▍                                                      |91/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▍                                                      |91/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▍                                                      |91/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▌                                                      |93/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▌                                                      |93/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:   9%|█████▌                                                      |93/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▋                                                      |95/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▋                                                      |95/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▋                                                      |95/1000, best_cost=0.445
# pyswarms.single.global_best:  10%|█████▊                                                      |97/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▊                                                      |97/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▊                                                      |97/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                      |99/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                      |99/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                      |99/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                     |101/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                     |101/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|█████▉                                                     |101/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████                                                     |103/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████                                                     |103/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████                                                     |103/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▏                                                    |105/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▏                                                    |105/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▏                                                    |105/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▎                                                    |107/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▎                                                    |107/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▎                                                    |107/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▍                                                    |109/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▍                                                    |109/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▍                                                    |109/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▌                                                    |111/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▌                                                    |111/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▌                                                    |111/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▋                                                    |113/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▋                                                    |113/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  11%|██████▋                                                    |113/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▊                                                    |115/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▊                                                    |115/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▊                                                    |115/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▉                                                    |117/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▉                                                    |117/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|██████▉                                                    |117/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████                                                    |119/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████                                                    |119/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████                                                    |119/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▏                                                   |121/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▏                                                   |121/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▏                                                   |121/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▎                                                   |123/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▎                                                   |123/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▎                                                   |123/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▍                                                   |125/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▍                                                   |125/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  12%|███████▍                                                   |125/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▍                                                   |127/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▍                                                   |127/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▍                                                   |127/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▌                                                   |129/1000, best_cost=0.445
# pyswarms.single.global_best:  13%|███████▌                                                   |129/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▌                                                   |129/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▋                                                   |131/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▋                                                   |131/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▋                                                   |131/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▊                                                   |133/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▊                                                   |133/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  13%|███████▊                                                   |133/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|███████▉                                                   |135/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|███████▉                                                   |135/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████                                                   |136/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████                                                   |136/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████                                                   |137/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████                                                   |137/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████                                                   |137/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▏                                                  |139/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▏                                                  |139/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▏                                                  |139/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▎                                                  |141/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▎                                                  |141/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▎                                                  |141/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▍                                                  |143/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▍                                                  |143/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▍                                                  |143/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▌                                                  |145/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  14%|████████▌                                                  |145/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▌                                                  |146/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▌                                                  |146/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▌                                                  |146/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▋                                                  |148/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▋                                                  |148/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▋                                                  |148/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▊                                                  |150/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▊                                                  |150/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▊                                                  |150/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▉                                                  |152/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▉                                                  |152/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|████████▉                                                  |152/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████                                                  |154/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████                                                  |154/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████                                                  |154/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▏                                                 |156/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▏                                                 |156/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▏                                                 |156/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▎                                                 |158/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▎                                                 |158/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▎                                                 |158/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▍                                                 |160/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▍                                                 |160/1000, best_cost=0.445
# pyswarms.single.global_best:  16%|█████████▍                                                 |160/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▌                                                 |162/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▌                                                 |162/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▌                                                 |162/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▋                                                 |164/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▋                                                 |164/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  16%|█████████▋                                                 |164/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▊                                                 |166/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▊                                                 |166/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▊                                                 |166/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▉                                                 |168/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▉                                                 |168/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|█████████▉                                                 |168/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████                                                 |170/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████                                                 |170/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████                                                 |170/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▏                                                |172/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▏                                                |172/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▏                                                |172/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▎                                                |174/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▎                                                |174/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  17%|██████████▎                                                |174/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▍                                                |176/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▍                                                |176/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▍                                                |176/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |178/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |178/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |178/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |180/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |180/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▌                                                |180/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▋                                                |182/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▋                                                |182/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▋                                                |182/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▊                                                |184/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▊                                                |184/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  18%|██████████▊                                                |184/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|██████████▉                                                |186/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|██████████▉                                                |186/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|██████████▉                                                |186/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████                                                |188/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████                                                |188/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████                                                |188/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▏                                               |190/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▏                                               |190/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▏                                               |190/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▎                                               |192/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▎                                               |192/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▎                                               |192/1000, best_cost=0.445
# pyswarms.single.global_best:  19%|███████████▍                                               |194/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▍                                               |194/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  19%|███████████▍                                               |194/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▌                                               |196/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▌                                               |196/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▌                                               |196/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▋                                               |198/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▋                                               |198/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▋                                               |198/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▊                                               |200/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▊                                               |200/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▊                                               |200/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▉                                               |202/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▉                                               |202/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|███████████▉                                               |202/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████                                               |204/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████                                               |204/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████                                               |204/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▏                                              |206/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▏                                              |206/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▏                                              |206/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▎                                              |208/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▎                                              |208/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▎                                              |208/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▍                                              |210/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▍                                              |210/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▍                                              |210/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▌                                              |212/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▌                                              |212/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▌                                              |212/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▋                                              |214/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▋                                              |214/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  21%|████████████▋                                              |214/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|████████████▋                                              |216/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|████████████▋                                              |216/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|████████████▋                                              |216/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|████████████▊                                              |218/1000, best_cost=0.445
#
#
#
#
#
#
#
#
#
#
#
# pyswarms.single.global_best:  22%|████████████
- pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.44516712552415966, best pos: [ 2.12193746  2.48379156  2.2077511   1.4764564   1.17095124  2.39953213
#   1.04589596  1.08100461  1.72785394  1.72574644  2.06615869  1.68935246
#   1.95304311  1.80095302  1.80639416  1.65006313  2.06974925  1.37816971
#   1.93494305  2.19321398  1.90032412  1.94186774  0.98300671  1.81568146
#   1.8604695   0.92751388  1.41278198  1.88751916  1.34043425  1.65087732
#   1.19697927  1.4271405   2.04611606  1.78772649  1.48749319  1.92426717
#   1.41276491  2.06879534  1.38781542  1.55518063  1.78143041  1.46752246
#   0.6308681   1.57974783  1.93415827  1.47026557  1.92370225  2.61509862
#   1.914063    1.6068147   1.43138521  1.45931867  2.31807958  1.72012561
#   1.15597086  0.75852061  1.14165277  1.38841028  1.26390229  2.66390645
#   1.74068162  2.22630473  1.87611025  1.21114233  0.1082636   1.01658331
#   1.49647574  1.9229376   2.13405088  1.8504075   1.43055379  1.84064721
#   1.84590746  2.47224863  0.69548148  1.94253179  2.21373972  1.45670846
#   2.01063312  2.41313153  0.8195684   1.84237522  2.34087329  0.99874638
#   2.63883405  1.48895229  2.96709827  2.12251998  2.33059005  1.74851313
#   1.17649925  2.26777152  1.84306274  1.50804428  1.23105317  1.87766663
#   2.02489338  2.09176111  1.95588713  1.94342124  1.35149603  1.21169704
#   1.31859444  2.17531698  1.0602284   1.32413027  1.68206061  1.74484687
#   1.57092307  3.34481045  2.41603948  1.44636998  2.01834256  2.10320818
#   1.42396448  2.1513326   1.53297756  1.77085514  1.21574748  1.11627501
#   1.30767242  2.26684715  2.51840946  1.82028856  0.99778485  1.48398466
#   1.38372751  2.15444786  1.85902126  1.39197084  1.99448159  2.4168019
#   0.82912596  1.74164727  1.53089203  1.8320497   2.31538461  1.99053182
#   2.37622505  1.40185063  1.19422275  1.28548163  1.94667511  1.29906611
#   2.05128624  1.11478996  1.52738221  1.81783095  1.24728431  2.1019532
#   1.9501397   1.75943274  2.04688033  1.29419119  1.39559712  1.71933565
#   1.97625071  2.1943308   1.85972148  2.54210757  2.22484142  1.61323854
#   0.89068262]
# Wall time: 1min 40s

# %%
def predict(X, pos):
    """
    Use the trained weights to perform class predictions.

    Inputs
    ------
    X: numpy.ndarray
        Input Iris dataset
    pos: numpy.ndarray
        Position matrix found by the swarm. Will be rolled
        into weights and biases.
    """
    # Neural network architecture
    n_inputs = 12
    n_hidden = 5
    n_classes = 3

    # Roll-back the weights and biases
    W1 = pos[0:60].reshape((n_inputs,n_hidden))
    b1 = pos[60:65].reshape((n_hidden,))
    W2 = pos[65:80].reshape((n_hidden,n_classes))
    b2 = pos[80:83].reshape((n_classes,))

    # Perform forward propagation
    z1 = X.dot(W1) + b1  # Pre-activation in Layer 1
    a1 = np.tanh(z1)     # Activation in Layer 1
    z2 = a1.dot(W2) + b2 # Pre-activation in Layer 2
    logits = z2          # Logits for Layer 2

    y_pred = np.argmax(logits, axis=1)
    return y_pred


(predict(X, pos) == y).mean()
# Out:
# 0.85292782569223791
